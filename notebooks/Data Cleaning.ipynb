# %% [markdown]
# **Exploring Python Data Science Packages by Aana Kakroo (20BAI1138)**

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Import the required Python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
from datetime import datetime

# %% [markdown]
# Load the datasets and display them

# %%
#load features.csv
features = pd.read_csv("https://raw.githubusercontent.com/aana0308/Walmart-Sales-Prediction/main/data/features.csv")
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
#load stores.csv
stores = pd.read_csv("https://raw.githubusercontent.com/aana0308/Walmart-Sales-Prediction/main/data/stores.csv")
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
#load train.csv
train = pd.read_csv("https://raw.githubusercontent.com/aana0308/Walmart-Sales-Prediction/main/data/train.csv")
train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
#load test.csv
test = pd.read_csv("https://raw.githubusercontent.com/aana0308/Walmart-Sales-Prediction/main/data/test.csv")
test
# Out:
#         Store  Dept        Date  IsHoliday
# 0           1     1  2012-11-02      False
# 1           1     1  2012-11-09      False
# 2           1     1  2012-11-16      False
# 3           1     1  2012-11-23       True
# 4           1     1  2012-11-30      False
# ...       ...   ...         ...        ...
# 115059     45    98  2013-06-28      False
# 115060     45    98  2013-07-05      False
# 115061     45    98  2013-07-12      False
# 115062     45    98  2013-07-19      False
# 115063     45    98  2013-07-26      False
#
# [115064 rows x 4 columns]

# %% [markdown]
# Checking the number of rows and columns in each dataset

# %%
features.shape
# Out:
# (8190, 12)

# %%
stores.shape
# Out:
# (45, 3)

# %%
train.shape
# Out:
# (421570, 5)

# %%
test.shape
# Out:
# (115064, 4)

# %% [markdown]
# Get information on the data types of each column in the datasets provided

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Store      115064 non-null  int64
#  1   Dept       115064 non-null  int64
#  2   Date       115064 non-null  object
#  3   IsHoliday  115064 non-null  bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 2.7+ MB

# %% [markdown]
# Get statistical information about the data in the provided datasets

# %%
features.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# ...

# %%
stores.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
train.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
test.describe()
# Out:
#                Store           Dept
# count  115064.000000  115064.000000
# mean       22.238207      44.339524
# std        12.809930      30.656410
# min         1.000000       1.000000
# 25%        11.000000      18.000000
# 50%        22.000000      37.000000
# 75%        33.000000      74.000000
# max        45.000000      99.000000

# %% [markdown]
# From the above descriptions of the datasets we can observe that there is a lot of difference between the minimum and maximum of the data and the standard deviation is quite high, thus we must detect and minimise the effect of outliers in the dataset

# %% [markdown]
# Checking the amount of NULL or missing values

# %%
features.isna().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
stores.isna().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
train.isna().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
test.isna().sum()
# Out:
# Store        0
# Dept         0
# Date         0
# IsHoliday    0
# dtype: int64

# %% [markdown]
# Drop rows in datasets with NULL or missing values (from features dataframe as it is the only one having missing or NULL values)

# %%
features = features.dropna()
features.isna().sum()
# Out:
# Store           0
# Date            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday       0
# dtype: int64

# %% [markdown]
# Merging (inner) stores and features dataframes on Store column

# %%
merge_df = features.merge(stores, how = 'inner', on = 'Store')
merge_df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  2069.000000  2069.000000  2069.000000    2069.000000    2069.000000
# mean     20.386660    52.516979     3.600298    9717.665297    4426.859778
# std      12.076174    18.483053     0.279335   11377.636869   10154.658061
# min       1.000000    -7.290000     2.872000    -563.900000    -265.760000
# 25%      10.000000    38.100000     3.409000    3542.800000      67.990000
# 50%      20.000000    51.420000     3.610000    6397.720000     404.610000
# 75%      29.000000    66.610000     3.796000   11265.620000    3900.310000
# max      45.000000    95.910000     4.301000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment  \
# count    2069.000000   2069.000000    2069.000000  2069.000000   2069.000000
# mean     2247.535911   4213.162687    5056.916061   175.587370      7.252611
# ...

# %%
#Converting date from object to datetime 

merge_df['Date'] = pd.to_datetime(merge_df['Date'])
train['Date'] = pd.to_datetime(train['Date'])
test['Date'] = pd.to_datetime(test['Date'])

# %%
#Extracting week, year from the data and making them into new columns

merge_df['week'] = merge_df.Date.dt.isocalendar().week
merge_df['year'] = merge_df.Date.dt.isocalendar().year

# %%
merge_df.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 2064     45 2013-03-01        39.72       3.890    6614.32     147.82
# 2065     45 2013-03-08        36.13       3.860   16382.54      88.67
# 2066     45 2013-04-05        43.94       3.763   16427.83    5341.41
# 2067     45 2013-04-12        57.39       3.724    8760.15    1713.11
# 2068     45 2013-04-19        56.27       3.676    1399.81      39.89
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 2064       5.60      27.55    1668.95  193.122173         8.625      False
# 2065      34.62    3096.92    3486.91  193.211524         8.625      False
# 2066     182.59    1523.83    1743.09  193.516047         8.335      False
# 2067      21.08    1302.31    1380.74  193.589304         8.335      False
# 2068      44.38      60.83    1445.05  193.589304         8.335      False
#
#      Type    Size  week  year
# 2064    B  118221     9  2013
# 2065    B  118221    10  2013
# ...

# %% [markdown]
# Creating a new dataframe by merging (inner) the train and newly merged dataframe merge_df on store, date and isholiday columns and sorting the values by store, department and date

# %%
train_df = train.merge(merge_df, how = 'inner', on = ['Store','Date','IsHoliday']).sort_values(by = ['Store','Dept','Date']).reset_index(drop = True)
train_df
# Out:
#        Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0          1     1 2011-11-11      18689.54      False        59.11
# 1          1     1 2011-11-18      19050.66      False        62.25
# 2          1     1 2011-11-25      20911.25       True        60.14
# 3          1     1 2011-12-02      25293.49      False        48.91
# 4          1     1 2011-12-09      33305.92      False        43.93
# ...      ...   ...        ...           ...        ...          ...
# 97051     45    98 2012-08-31        346.04      False        75.09
# 97052     45    98 2012-09-07        352.44       True        75.70
# 97053     45    98 2012-09-21        467.30      False        65.32
# 97054     45    98 2012-09-28        508.37      False        64.88
# 97055     45    98 2012-10-26       1076.80      False        58.85
#
#        Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0           3.297   10382.90    6115.67     215.07    2406.62    6551.42
# ...

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# Scatter Plot

# %%
#plot a scatter plot using the scatter function a scatter plot of weekly sales with respect to store
#plot the figure
plt.figure()

#plot the scatter plot with data from the specified column in x axis and weekly sales in y axis
plt.scatter(train_df['Store'],train_df['Weekly_Sales'])

#give y label as Weekly Sales
plt.ylabel('Weekly_Sales')

#give the x label as the column specified as parameter in the function
plt.xlabel('Store')
# Out:
# Text(0.5, 0, 'Store')

# %%
#plot a scatter plot using the scatter function a scatter plot of weekly sales with respect to department
#plot the figure
plt.figure()

#plot the scatter plot with data from the specified column in x axis and weekly sales in y axis
plt.scatter(train_df['Dept'],train_df['Weekly_Sales'])

#give y label as Weekly Sales
plt.ylabel('Weekly_Sales')

#give the x label as the column specified as parameter in the function
plt.xlabel('Dept')
# Out:
# Text(0.5, 0, 'Dept')

# %% [markdown]
# Line plots for weekly sales for each year

# %%
#Filtering out mean weekly sales for the year 2010
weekly_sales_2010 = train_df[train_df['year']==2010]['Weekly_Sales'].groupby(train_df['week']).mean()

#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis 
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values, color = 'red')
# Out:
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
#Filtering out mean weekly sales for the year 2011
weekly_sales_2011 = train_df[train_df['year']==2011]['Weekly_Sales'].groupby(train_df['week']).mean()

#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis 
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values, color = 'black')
# Out:
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %%
#Filtering out mean weekly sales for the year 2012
weekly_sales_2012 = train_df[train_df['year']==2012]['Weekly_Sales'].groupby(train_df['week']).mean()

#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis 
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values, color = 'darkgreen')
# Out:
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %%
#plotting a figure
plt.figure(figsize = (20,10))

#plotting three lineplots for weekly sales for each year
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values, color = 'crimson')
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values, color = 'navy')
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values, color = 'darkgreen')

plt.grid()

#plot labels and legends
plt.xticks(np.arange(1,60,step = 1))
plt.title('Average weekly sales per year', fontsize = 22)
plt.xlabel('week', fontsize = 18)
plt.ylabel('sales', fontsize = 18)
plt.legend(['2010','2011','2012'], fontsize = 18)
# Out:
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#plotting a figure
plt.figure(figsize = (20,10))

#plotting three lineplots for weekly sales for each year
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values, color = 'crimson')
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values, color = 'navy')
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values, color = 'darkgreen')

plt.grid()

#plot labels and legends
plt.xticks(np.arange(1,60,step = 1))
plt.title('Average weekly sales per year', fontsize = 22)
plt.xlabel('week', fontsize = 18)
plt.ylabel('sales', fontsize = 18)
plt.legend(['2010','2011','2012'], fontsize = 18)
# Out:
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Histogram

# %%
sns.distplot(train_df['Weekly_Sales'], color = 'orangered')
# Out:
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %%
train_df['Weekly_Sales'].kurt()

#kutosis is a measure of whether the data is heavy-tailed or light-tailed to normal distribution
# Out:
# 19.004442627496726

# %% [markdown]
# Bar chart on dataframe

# %%
weekly_sales_store = train_df['Weekly_Sales'].groupby(train_df['Store']).mean()
weekly_sales_store
# Out:
# Store
# 1     22503.217661
# 2     27381.813232
# 3      6626.084529
# 4     30948.432055
# 5      5298.231332
# 6     22426.225998
# 7      9307.772681
# 8     13558.938390
# 9      9126.063820
# 10    27642.625426
# 11    19487.016589
# 12    15566.935453
# 13    28649.644419
# 14    27073.815064
# 15     9003.104264
# 16     8047.348701
# 17    13613.396289
# 18    15791.340238
# 19    20280.619293
# 20    30325.022256
# 21    11325.493090
# 22    14923.195201
# 23    20590.635692
# 24    18934.994143
# 25    10604.817076
# 26    14509.908597
# 27    24205.399499
# 28    18681.518696
# 29     8170.253532
# 30     8469.759299
# 31    20166.562969
# 32    16989.653570
# 33     4965.568969
# 34    14115.588145
# 35    12408.618692
# 36     7232.159767
# 37     9497.658962
# 38     8260.233489
# 39    22976.959484
# 40    13947.301438
# 41    18961.131482
# 42    11351.177600
# 43    13775.235761
# 44     6192.617143
# 45    11955.409517
# Name: Weekly_Sales, dtype: float64

# %%
#converting to dataframe
weekly_sales_store_df = pd.DataFrame(weekly_sales_store)

# %%
weekly_sales_store_df.sort_values('Weekly_Sales', ascending = False).style.bar(align = 'left', width = 98, color = 'cyan')
# Out:
# <style type="text/css">
# #T_23d65_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 98.0%, transparent 98.0%);
# }
# #T_23d65_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 95.6%, transparent 95.6%);
# }
# #T_23d65_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 89.3%, transparent 89.3%);
# }
# #T_23d65_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 85.5%, transparent 85.5%);
# }
# #T_23d65_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 84.5%, transparent 84.5%);
# }
# #T_23d65_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 83.4%, transparent 83.4%);
# }
# #T_23d65_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 72.6%, transparent 72.6%);
# }
# #T_23d65_row7_col0 {
#   width: 10em;
#   height: 80%;
# ...

# %%
#opposite order
weekly_sales_store_df.sort_values('Weekly_Sales').style.bar(align = 'left', width = 98, color = 'cyan')
# Out:
# <style type="text/css">
# #T_dccc3_row0_col0 {
#   width: 10em;
#   height: 80%;
# }
# #T_dccc3_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 1.3%, transparent 1.3%);
# }
# #T_dccc3_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 4.6%, transparent 4.6%);
# }
# #T_dccc3_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 6.3%, transparent 6.3%);
# }
# #T_dccc3_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 8.5%, transparent 8.5%);
# }
# #T_dccc3_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 11.6%, transparent 11.6%);
# }
# #T_dccc3_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 12.1%, transparent 12.1%);
# }
# #T_dccc3_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,cyan 12.4%, transparent 12.4%);
# }
# ...

# %% [markdown]
# Plotting a bar graph with store number as x values and mean weekly sales for that store as y values

# %%
#plotting the figure
plt.figure(figsize = (20,10))

#create a barplot with stores in x axis and mean weekly sales in y axis 
sns.barplot(weekly_sales_store.index, weekly_sales_store.values, palette = 'bright')
plt.grid()
plt.title('Average weekly sales per store', fontsize = 22)
plt.xlabel('Store Number', fontsize = 18)
plt.ylabel('Sales per store', fontsize = 18)
# Out:
# C:\Users\aanak\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Sales per store')

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize = (20,15))
sns.heatmap(train_df.corr(), annot = True )
# Out:
# <AxesSubplot:>
